# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroConst/Python-Bioprocessos/blob/main/Dia01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python para Engenharia de Bioprocessos**
# ### Da análise de dados à simulação de crescimento microbiano
#
#  Como podemos utilizar Python para analisar e modelar o crescimento de uma cultura microbiana?

# %% [markdown]
# ## **Bem-vindo!**
#
# Neste minicurso, vamos explorar como ferramentas computacionais modernas podem auxiliar engenheiros na análise, modelagem e otimização de bioprocessos.
#
# Ao longo dos próximos dois dias utilizaremos a linguagem Python para resolver problemas inspirados em situações encontradas na indústria e na pesquisa, passando desde a manipulação de dados experimentais até a construção de modelos matemáticos e modelos baseados em Machine Learning.
#
# Nenhum conhecimento prévio de programação é necessário. Todos os exemplos serão desenvolvidos passo a passo.
#
#
# ---
#
#
#
# ### **O desafio: Produção sustentável de bioplásticos**
#
#
# O descarte inadequado de plásticos convencionais representa um dos principais desafios ambientais da atualidade. Como alternativa, diversas empresas têm investido na produção de bioplásticos biodegradáveis obtidos por fermentação microbiana. Um dos materiais mais promissores é o polihidroxibutirato (PHB), um polímero produzido naturalmente por algumas bactérias e que apresenta propriedades semelhantes às de plásticos convencionais, porém com menor impacto ambiental.
#
# Uma empresa de biotecnologia está desenvolvendo um novo processo fermentativo utilizando melaço de cana-de-açucar, uma fonte renovável de carbono, para reduzir os custos de produção de PHB em escala industrial. Embora os resultados iniciais sejam promissores, cada experimento realizado no laboratório consome dias de trabalho, reagentes e recursos financeiros. Dessa forma, antes de ampliar a quantidade de experimentos, a equipe de engenharia decidiu utilizar ferramentas computacionais para compreender melhor o processo e orientar o planejamento das próximas etapas.
#
# Você acaba de ser contratado para integrar essa equipe.
#
#
# ---
# Ao longo do minicurso, você fará parte dessa equipe e deverá responder perguntas como:
#
# - O microrganismo está crescendo conforme o esperado?
# - Como interpretar os dados experimentais?
# - É possível construir um modelo matemático para descrever a fermentação?
# - Como estimar parâmetros do modelo?
# - Um algoritmo de Machine Learning consegue prever o comportamento do processo?
#
# Cada ferramenta apresentada durante o curso contribuirá para responder uma dessas perguntas.
#
#
# ---
# ### **O que você aprenderá hoje?**
#
# No primeiro dia iremos construir a base necessária para analisar dados experimentais e desenvolver os primeiros modelos computacionais do processo.
#
# No segundo dia utilizaremos essas ferramentas para calibrar modelos, realizar previsões e introduzir técnicas modernas de Machine Learning.
#
# ---

# %% [markdown]
# ###**Primeira atividade**
#
# Antes de começarmos, execute a célula abaixo para verificar se o ambiente está funcionando corretamente.

# %%
print("Bem-vindo ao Workshop Python para Engenharia de Bioprocessos!")

# %% [markdown]
# ## **Passo 1 – Python como calculadora científica**
#
# Antes de trabalhar com modelos matemáticos, análise de dados ou Machine Learning, precisamos conhecer a ferramenta que será utilizada ao longo de todo o minicurso.
#
# Embora Python seja uma linguagem de programação bastante poderosa, podemos começar utilizando-a como uma calculadora científica muito mais flexível do que uma calculadora convencional. Além das operações matemáticas básicas, Python permite organizar cálculos, reutilizar resultados e automatizar tarefas repetitivas, características essenciais em aplicações de engenharia.

# %% [markdown]
# ### Operações matemáticas básicas
#
# Python reconhece os principais operadores matemáticos.
#
# | Operação | Símbolo |
# |-----------|----------|
# | Soma | `+` |
# | Subtração | `-` |
# | Multiplicação | `*` |
# | Divisão | `/` |
# | Potência | `**` |
# | Resto da divisão | `%` |
#
# Execute a célula abaixo e observe os resultados.

# %%
2 + 3

# %%
7 - 4

# %%
5 * 8

# %%
10 / 3

# %%
2 ** 2

# %%
2 ** 5

# %% [markdown]
# Observe que a divisão entre dois números inteiros produz um número decimal.
#
# Também é possível utilizar parênteses para definir a ordem das operações, exatamente como em uma expressão matemática.

# %%
resultado1 = 2 + 3 * 4
resultado2 = (2 + 3) * 4

print(resultado1)
print(resultado2)

# %% [markdown]
# ### Variáveis
#
# Uma variável funciona como uma "caixa" onde armazenamos um valor para utilizá-lo posteriormente.
#
# Em Engenharia, trabalhamos constantemente com grandezas físicas como temperatura, concentração, vazão e volume. Utilizar variáveis torna o código mais organizado e muito mais fácil de interpretar.

# %%
temperatura = 37          # °C
volume = 2.5              # L
concentracao = 4.2        # g/L

print("Temperatura:", temperatura)
print("Volume:", volume)
print("Concentração:", concentracao)

# %% [markdown]
# Também podemos realizar operações utilizando variáveis.

# %%
massa = volume * concentracao

print("Massa de biomassa =", massa, "g")

# %% [markdown]
# ### Exemplo 1 — Quantidade de biomassa em um biorreator
#
# Durante um experimento para produção de PHB, um biorreator contém **3,5 L** de meio de cultivo.
#
# Ao final da fase de crescimento, a concentração celular medida foi de **2,8 g/L**.
#
# Qual é a massa total de biomassa presente no reator?

# %%
volume = 3.5          # L
X = 2.8               # g/L

massa = volume * X

print(f"Massa de biomassa = {massa:.2f} g")

# %% [markdown]
# ### Conversão de unidades
#
# Grande parte dos erros em cálculos de engenharia está relacionada a conversões incorretas de unidades.
#
# Python facilita esse tipo de cálculo e reduz significativamente a possibilidade de erros.

# %%
concentracao = 5      # g/L

concentracao_SI = concentracao * 1

print(concentracao_SI, "kg/m³")

# %%
volume = 2500      # mL

volume_L = volume / 1000

print(volume_L,"L")

# %% [markdown]
# ### Exercício
#
# Um biorreator possui **5 L** de meio de cultivo contendo uma concentração celular de **4,8 g/L**.
#
# 1. Calcule a massa total de biomassa.
# 2. Converta o volume para m³.

# %% [markdown]
# ### Desafio
#
# O processo será ampliado para um biorreator de **250 L**, mantendo a mesma concentração celular.
#
# Qual será a massa total de biomassa produzida?
#
# Como esse valor muda se a concentração aumentar em 25%?

# %% [markdown]
# ### Conectando com o nosso desafio
#
# Até agora utilizamos Python apenas como uma calculadora científica.
#
# Nos próximos tópicos veremos como realizar cálculos com centenas ou milhares de dados simultaneamente, construir gráficos e, posteriormente, desenvolver modelos matemáticos capazes de descrever o crescimento microbiano durante a produção de PHB.
#
# A partir deste ponto, Python deixará de ser apenas uma calculadora e passará a ser uma ferramenta de engenharia.

# %% [markdown]
# ## **Passo 2 – Trabalhando com conjuntos de dados usando NumPy**
#
# Na seção anterior utilizamos Python para realizar cálculos envolvendo valores individuais.
#
# Entretanto, em aplicações reais de engenharia raramente trabalhamos com apenas um número. Durante um experimento de fermentação, por exemplo, são realizadas diversas medições ao longo do tempo, como concentração celular, concentração de substrato, temperatura e pH.
#
# Para armazenar e manipular esse tipo de informação de forma eficiente utilizaremos a biblioteca **NumPy**, uma das ferramentas mais importantes da computação científica em Python.
#
# Ao longo deste minicurso, praticamente todos os cálculos serão realizados utilizando arrays do NumPy.

# %% [markdown]
# ### Importando bibliotecas
#
# Bibliotecas são conjuntos de funções desenvolvidas para realizar tarefas específicas.
#
# Neste curso utilizaremos diversas bibliotecas. A primeira delas é o **NumPy**, que fornece estruturas de dados e operações matemáticas eficientes para computação científica.
#
# Por convenção, importamos o NumPy utilizando o apelido `np`.

# %%
import numpy as np

# %% [markdown]
# ### Dados experimentais de um cultivo
#
# Considere que a equipe responsável pelo processo realizou medições da concentração celular ao longo de uma fermentação para produção de PHB.
#
# As medições obtidas foram:

# %%
tempo = np.array([0, 2, 4, 6, 8, 10])          # h

biomassa = np.array([0.10, 0.18, 0.33, 0.60, 1.05, 1.80])   # g/L

# %%
tempo

# %%
biomassa

# %% [markdown]
# Um **array** pode ser entendido como uma coleção organizada de valores do mesmo tipo.
#
# Enquanto uma variável armazena apenas um número, um array permite armazenar dezenas, centenas ou milhares de medições experimentais em uma única estrutura.
#
# Isso torna possível realizar cálculos sobre todo o conjunto de dados de uma só vez.

# %%
biomassa * 2

# %%
biomassa + 1

# %%
biomassa / 10

# %% [markdown]
# ### Estatísticas
#
# Podemos usar funções prontas da biblioteca Numpy!

# %%
np.mean(biomassa)

# %%
np.max(biomassa)

# %%
np.min(biomassa)

# %%
np.sum(biomassa)

# %% [markdown]
# ### Localizando informações

# %%
biomassa[0]

# %%
biomassa[-1]

# %%
tempo[3]

# %% [markdown]
# Essas funções são extremamente úteis na análise de dados experimentais e serão utilizadas diversas vezes ao longo do minicurso.

# %% [markdown]
# ### Operações entre arrays
#
# Podemos calcular a variação da biomassa entre medições consecutivas.

# %%
biomassa[1:]

# %%
biomassa[:-1]

# %%
deltaX = biomassa[1:] - biomassa[:-1]

deltaX

# %% [markdown]
# ### Criando dados automaticamente

# %%
tempo = np.linspace(0,10,6)

tempo

# %%
tempo = np.linspace(0,10,100)

tempo

# %% [markdown]
# ### Exercício
#
# Considere as seguintes concentrações de substrato medidas durante a fermentação.

# %%
substrato = np.array([20.0,18.5,16.7,14.0,10.8,7.2])

# %% [markdown]
# Calcule:
#
# - Concentração média, máxima e mínima
# - Consumo total de substrato

# %% [markdown]
# ### Desafio
#
# Calcule automaticamente a conversão do substrato em cada instante utilizando
#
# $$
# X = \frac{S_0-S}{S_0}
# $$
#
# O resultado deve ser um novo array contendo a conversão ao longo do tempo.

# %% [markdown]
# ### Aplicação em Engenharia
#
# Durante o desenvolvimento de um bioprocesso, é comum que centenas de experimentos sejam realizados e que cada experimento gere milhares de medições.
#
# Manipular essas informações manualmente seria inviável.
#
# Bibliotecas como o NumPy permitem que esses dados sejam armazenados e processados de forma rápida e eficiente, constituindo a base para etapas mais avançadas, como visualização de dados, ajuste de modelos matemáticos e algoritmos de Machine Learning.

# %% [markdown]
# Até o momento conseguimos armazenar e realizar cálculos com nossos dados experimentais.
#
# No entanto, tabelas de números nem sempre permitem identificar tendências importantes. O próximo passo será transformar esses dados em gráficos, uma das ferramentas mais importantes para análise e interpretação de experimentos.

# %% [markdown]
# ## **Passo 3 – Visualização de dados com Matplotlib**
#
# Até o momento armazenamos e analisamos nossos dados utilizando arrays do NumPy.
#
# Entretanto, uma tabela de números nem sempre permite identificar padrões importantes. Em engenharia, a visualização gráfica é uma das ferramentas mais importantes para interpretar resultados experimentais, comparar diferentes condições operacionais e identificar possíveis erros de medição.
#
# Nesta seção aprenderemos a construir gráficos utilizando a biblioteca **Matplotlib**, uma das ferramentas mais utilizadas para visualização de dados em Python.

# %% [markdown]
# ### Importando o Matplotlib
#
# Assim como fizemos com o NumPy, precisamos importar a biblioteca que será utilizada para gerar os gráficos.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Primeiro gráfico
#
# Vamos utilizar novamente os dados do experimento de produção de PHB.

# %%
tempo = np.array([0,2,4,6,8,10])

biomassa = np.array([0.10,0.18,0.33,0.60,1.05,1.80])

# %%
plt.plot(tempo, biomassa)
plt.show()

# %%
plt.figure(figsize=(6,4))

plt.plot(tempo, biomassa)

plt.xlabel("Tempo (h)")
plt.ylabel("Biomassa (g/L)")
plt.title("Crescimento celular durante a fermentação")

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.plot(tempo, biomassa, marker='o')

plt.xlabel("Tempo (h)")
plt.ylabel("Biomassa (g/L)")
plt.title("Crescimento celular durante a fermentação")

plt.show()

# %%
plt.figure(figsize=(7,4))

plt.plot(
    tempo,
    biomassa,
    marker='o',
    linewidth=2,
    markersize=7
)

plt.grid(True)

plt.xlabel("Tempo (h)")
plt.ylabel("Biomassa (g/L)")

plt.title("Produção de biomassa durante a fermentação")

plt.show()

# %% [markdown]
# ### Comparando dois experimentos
#
# A empresa realizou um segundo experimento utilizando uma condição operacional diferente.
#
# Será que houve melhora no crescimento celular?

# %%
biomassa2 = np.array([0.10,0.22,0.42,0.75,1.30,2.10])

# %%
plt.figure(figsize=(7,4))

plt.plot(
    tempo,
    biomassa,
    marker='o',
    label='Experimento 1'
)

plt.plot(
    tempo,
    biomassa2,
    marker='s',
    label='Experimento 2'
)

plt.xlabel("Tempo (h)")
plt.ylabel("Biomassa (g/L)")

plt.legend()

plt.grid(True)

plt.show()

# %% [markdown]
# ### 🔍 Interpretando os resultados
#
# Observa-se que ambos os experimentos apresentam crescimento celular ao longo do tempo. Entretanto, o Experimento 2 atinge concentrações de biomassa significativamente maiores, indicando que a alteração das condições operacionais favoreceu o crescimento do microrganismo.
#
# Neste momento ainda não sabemos qual variável foi modificada nem por que houve essa diferença. Nos próximos tópicos construiremos modelos matemáticos capazes de explicar esse comportamento e quantificar o efeito dos parâmetros cinéticos.

# %% [markdown]
# ### Exercício
#
# Construa um gráfico da concentração de substrato ao longo da fermentação.

# %%
substrato = np.array([20.0,18.5,16.7,14.0,10.8,7.2])

# %% [markdown]
# ### Desafio
#
# Construa uma figura contendo:
#
# - Biomassa
# - Substrato
#
# no mesmo gráfico.
#
# Adicione uma legenda identificando cada curva.

# %% [markdown]
# ### Aplicação em Engenharia
#
# A inspeção visual dos dados é frequentemente a primeira etapa da análise de um experimento. Um gráfico bem elaborado permite identificar tendências, comparar diferentes condições operacionais e detectar possíveis inconsistências nos dados antes mesmo da realização de análises mais sofisticadas.
#
# Ao longo deste minicurso utilizaremos gráficos para interpretar experimentos, validar modelos matemáticos e comparar previsões obtidas por diferentes técnicas de modelagem.

# %% [markdown]
# ## **Passo 4 – Trabalhando com dados reais usando Pandas**
#
# A equipe do laboratório concluiu um novo experimento de fermentação e enviou os resultados em uma planilha (.csv). Agora cabe à equipe de engenharia importar esses dados, verificar se estão consistentes e prepará-los para análise.
#
# Até agora digitamos manualmente os dados experimentais diretamente no código. Embora isso seja útil para aprender os conceitos básicos, essa abordagem rapidamente se torna inviável em aplicações reais.
#
# Em laboratórios e indústrias, os resultados de experimentos normalmente são armazenados em planilhas ou arquivos de texto. A primeira etapa da análise de qualquer experimento consiste em importar esses dados para um ambiente computacional.
#
# Nesta seção aprenderemos a utilizar a biblioteca **Pandas**, uma das ferramentas mais importantes para manipulação e análise de dados em Python.

# %%
import pandas as pd

# %% [markdown]
# Enquanto o NumPy é excelente para cálculos numéricos, o Pandas foi desenvolvido para trabalhar com dados organizados em tabelas.
#
# O objeto principal do Pandas é o **DataFrame**, uma estrutura semelhante a uma planilha do Excel, onde cada coluna representa uma variável medida durante o experimento.
#
# Nos próximos capítulos praticamente todos os dados experimentais serão armazenados nesse formato.

# %%
dados = {
    "Tempo (h)": [0, 2, 4, 6, 8, 10],
    "Biomassa (g/L)": [0.10, 0.18, 0.33, 0.60, 1.05, 1.80],
    "Substrato (g/L)": [20.0, 18.5, 16.7, 14.0, 10.8, 7.2]
}

df = pd.DataFrame(dados)

df

# %%
df.head()

# %%
df.tail()

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
df["Biomassa (g/L)"]

# %%
df["Tempo (h)"]

# %%
df["Substrato (g/L)"]

# %%
plt.figure(figsize=(6,4))

plt.plot(df["Tempo (h)"],
         df["Biomassa (g/L)"],
         marker='o')

plt.xlabel("Tempo (h)")
plt.ylabel("Biomassa (g/L)")
plt.grid()

plt.show()

# %% [markdown]
# Na prática, não precisamos criar a tabela manualmente. Os dados normalmente são fornecidos em arquivos externos, como planilhas ou arquivos CSV.

# %%
df = pd.read_csv("fermentacao_phb.csv")

df.head()

# %% [markdown]
# ### Exercício
#
# Utilizando o DataFrame carregado:
#
# 1. Determine a biomassa máxima.
# 2. Determine o instante em que ela ocorreu.
# 3. Calcule a concentração média de substrato.
# 4. Construa novamente o gráfico da biomassa em função do tempo.

# %% [markdown]
# ### Desafio
#
# Crie uma nova coluna chamada **Conversão (%)**, definida por
#
# $$
# \text{Conversão}=\frac{S_0-S}{S_0}\times100
# $$
#
# e apresente a tabela atualizada.

# %% [markdown]
# ### Aplicação em Engenharia
#
# Em projetos industriais e de pesquisa, a análise de dados normalmente começa pela importação de informações provenientes de experimentos, sensores ou sistemas supervisórios. O Pandas fornece um conjunto de ferramentas que permite organizar, explorar e preparar esses dados para etapas posteriores, como visualização, modelagem matemática e treinamento de modelos de Machine Learning.
#
# Nos próximos tópicos utilizaremos esses mesmos dados para calcular parâmetros cinéticos e construir modelos capazes de descrever o crescimento microbiano durante a produção de PHB.

# %% [markdown]
# ## **Passo 5 – Análise da Taxa de Crescimento Microbiano**
#
# Até agora aprendemos a importar dados experimentais, manipulá-los e representá-los graficamente.
#
# O próximo passo consiste em extrair informações que nos ajudem a compreender o comportamento do processo fermentativo.
#
# Uma das grandezas mais importantes em Engenharia de Bioprocessos é a **taxa de crescimento microbiano**, que indica a velocidade com que a biomassa aumenta ao longo do tempo.
#
# Nesta seção utilizaremos os dados experimentais para calcular diferentes medidas de crescimento e interpretar seu significado físico.

# %% [markdown]
# ### Taxa média de crescimento
#
# Imagine que desejamos estimar a velocidade média de crescimento da biomassa entre duas medições consecutivas.
#
# Essa quantidade pode ser calculada pela razão entre a variação da concentração celular e o intervalo de tempo correspondente:
#
# $$
# r_X=\frac{\Delta X}{\Delta t}
# $$
#
# Essa grandeza representa o aumento médio da biomassa por unidade de tempo.

# %%
tempo = df["Tempo (h)"].values
biomassa = df["Biomassa (g/L)"].values

dX = np.diff(biomassa)
dt = np.diff(tempo)

rX = dX/dt

# %%
rX[:5]

# %%
df_taxa = pd.DataFrame()

df_taxa["Tempo médio (h)"] = (tempo[:-1]+tempo[1:])/2

df_taxa["Taxa média (g/L/h)"] = rX

df_taxa.head()

# %%
plt.figure(figsize=(7,4))

plt.plot(
    df_taxa["Tempo médio (h)"],
    df_taxa["Taxa média (g/L/h)"],
    marker='o'
)

plt.xlabel("Tempo (h)")
plt.ylabel("Taxa média (g/L/h)")

plt.grid()

plt.show()

# %% [markdown]
# ### 🔍 Interpretando os resultados
#
# Observe que a taxa média de crescimento não permanece constante ao longo da fermentação.
#
# Inicialmente, o crescimento é lento devido à pequena quantidade de biomassa presente no sistema.
#
# Posteriormente, a taxa aumenta, atingindo um valor máximo durante a fase exponencial.
#
# Nas etapas finais da fermentação, o crescimento torna-se mais lento em consequência da redução da disponibilidade de substrato e do acúmulo de produtos metabólicos.

# %% [markdown]
# ### Taxa específica de crescimento
#
# Embora a taxa média seja útil, ela depende diretamente da quantidade de biomassa presente no reator.
#
# Para comparar diferentes experimentos é mais conveniente utilizar a **taxa específica de crescimento**, definida como a velocidade de crescimento por unidade de biomassa.
#
# Para dois pontos experimentais consecutivos, podemos estimá-la por:
#
# $$
# μ=​\frac{ln(\frac{X_2}{X_1})}{t_2​−t_1}
# $$
#
# Quanto maior o valor de $\mu$, mais rapidamente a população microbiana cresce.
#
# Essa será uma das principais variáveis utilizadas na construção dos modelos matemáticos apresentados nas próximas seções.

# %%
mu = np.log(biomassa[1:]/biomassa[:-1])/dt

# %%
mu[:5]

# %%
df_taxa["Taxa específica (1/h)"] = mu

df_taxa.head()

# %%
plt.figure(figsize=(7,4))

plt.plot(
    df_taxa["Tempo médio (h)"],
    mu,
    marker='o'
)

plt.xlabel("Tempo (h)")
plt.ylabel("μ (1/h)")

plt.grid()

plt.show()

# %% [markdown]
# ### Pergunta
#
# - A taxa específica permanece constante durante toda a fermentação?
#
# - Quais fenômenos físicos podem explicar as variações observadas?
#
# Os resultados mostram que a taxa específica de crescimento não é constante.
#
# Em processos reais, o crescimento microbiano depende de diversos fatores, sendo a disponibilidade de substrato um dos mais importantes.
#
# Na próxima seção construiremos um modelo matemático capaz de descrever essa relação, conhecido como **modelo de Monod**.

# %% [markdown]
# ### Exercício
#
# Utilizando os dados experimentais:
#
# 1. Determine o maior valor da taxa específica de crescimento.
# 2. Em que instante da fermentação ele ocorre?
# 3. Qual é o valor médio da taxa específica ao longo do experimento?

# %% [markdown]
# ### Desafio
#
# Sabendo que a biomassa aumentou enquanto o substrato foi consumido, calcule a variação de biomassa e de substrato entre medições consecutivas.
#
# Com esses resultados, estime o rendimento observado do processo utilizando
#
# $$
# Y_{X/S}=\frac{\Delta X}{-\Delta S}
# $$
#
# Esse parâmetro será utilizado posteriormente para interpretar o desempenho do processo fermentativo.

# %% [markdown]
# ## **Passo 6 – Organizando Cálculos com Funções em Python**
#
# Até agora escrevemos códigos relativamente curtos. Entretanto, à medida que os problemas se tornam mais complexos, é comum precisarmos repetir os mesmos cálculos diversas vezes.
#
# Em programação, uma boa prática consiste em organizar esses cálculos em **funções**. Uma função recebe informações de entrada, realiza uma sequência de operações e retorna um resultado.
#
# Além de tornar o código mais organizado, as funções facilitam a reutilização de cálculos e reduzem a possibilidade de erros.
#
# Nesta seção aprenderemos esse conceito utilizando exemplos relacionados ao nosso processo de produção de PHB.

# %% [markdown]
# ### Um cálculo repetitivo
#
# Suponha que desejemos calcular repetidamente a massa de biomassa presente em diferentes biorreatores.
#
# Sabemos que:
#
# $$
# m=XV
# $$
#
# onde
#
# - $X$ é a concentração celular (g/L);
# - $V$ é o volume do reator (L).
#
# Em vez de repetir esse cálculo diversas vezes, podemos criar uma função.

# %%
def massa_biomassa(concentracao, volume):
    """
    Calcula a massa total de biomassa.

    Parâmetros
    ----------
    concentracao : float
        Concentração celular (g/L)

    volume : float
        Volume do reator (L)

    Retorna
    -------
    float
        Massa de biomassa (g)
    """

    massa = concentracao * volume

    return massa

# %%
massa = massa_biomassa(2.8, 3.5)

print(f"Massa = {massa:.2f} g")

# %%
massa_biomassa(4.5,10)

# %%
massa_biomassa(6.2,150)

# %%
massa = massa_biomassa(
    df["Biomassa (g/L)"].iloc[-1],
    3.5
)

print(massa)

# %% [markdown]
# ### Exemplo: rendimento biomassa/substrato
#
# Uma grandeza frequentemente utilizada em Engenharia de Bioprocessos é o rendimento de biomassa em relação ao substrato consumido:
#
# $$
# Y_{X/S}=\frac{\Delta X}{-\Delta S}
# $$
#
# Vamos criar uma função para realizar esse cálculo.

# %%
def rendimento(deltaX, deltaS):

    return deltaX/(-deltaS)

# %%
deltaX = 2.4
deltaS = -6.8

YXS = rendimento(deltaX, deltaS)

print(YXS)

# %%
deltaX = np.diff(df["Biomassa (g/L)"])

deltaS = np.diff(df["Substrato (g/L)"])

rendimento_exp = rendimento(deltaX, deltaS)

# %%
rendimento_exp

# %% [markdown]
# ### Exercício
#
# Crie uma função chamada
#
# ```python
# conversao(S0,S)
# ```
#
# que calcule a conversão do substrato
#
# $$
# X=\frac{S_0-S}{S_0}
# $$
#
# Utilize essa função para calcular a conversão em todos os instantes da fermentação.

# %% [markdown]
# ### Desafio
#
# Crie uma função que receba um vetor contendo concentrações de biomassa e retorne:
#
# - biomassa máxima;
# - biomassa mínima;
# - biomassa média.
#
# Dica:
#
# Utilize as funções do NumPy vistas anteriormente.

# %% [markdown]
# ### Aplicação em Engenharia
#
# À medida que um projeto evolui, os códigos utilizados para análise de dados e modelagem tornam-se cada vez maiores.
#
# Organizar cálculos em funções torna os programas mais legíveis, facilita a identificação de erros e permite reutilizar rotinas em diferentes experimentos.
#
# Nas próximas seções utilizaremos esse conceito para construir modelos matemáticos capazes de representar o crescimento microbiano durante a fermentação para produção de PHB.

# %% [markdown]
# ## **Passo 7 – Construindo um Modelo para o Crescimento Microbiano**
#
# Ao longo deste minicurso analisamos dados experimentais obtidos durante uma fermentação para produção de PHB.
#
# Mas será que é possível ir além da análise dos dados?
#
# Em Engenharia de Bioprocessos, frequentemente desejamos responder perguntas como:
#
# - O que acontecerá se aumentarmos a concentração inicial de substrato?
# - Quanto tempo será necessário para atingir uma determinada concentração celular?
# - Como diferentes condições operacionais afetam o crescimento microbiano?
#
# Responder essas perguntas realizando apenas experimentos pode ser caro e demorado. Por esse motivo, engenheiros utilizam **modelos matemáticos**, capazes de descrever o comportamento do sistema e realizar previsões antes mesmo da execução de novos experimentos.
#
# Nesta última seção do primeiro dia conheceremos um dos modelos mais importantes da Engenharia de Bioprocessos: o modelo de Monod.

# %% [markdown]
# ### O modelo mais simples possível
#
# Suponha que cada célula presente no biorreator se divida continuamente à mesma velocidade.
#
# Nesse caso, a velocidade de crescimento da biomassa será proporcional à quantidade de biomassa existente no sistema.
#
# Esse comportamento pode ser representado por:
#
# $$
# \frac{dX}{dt} = μX
# $$
#
# onde
#
# - $X$ é a concentração de biomassa;
# - $\mu$ é a taxa específica de crescimento. Observe que essa é exatamente a grandeza calculada na seção anterior.
#
# O modelo possui solução analítica:
#
# $$
# X=X_0 e^{μt}
# $$

# %% [markdown]
# ### 🔍 Interpretando o modelo
#
# Esse modelo afirma que quanto maior a quantidade de biomassa presente no reator, maior será a velocidade de crescimento da cultura.
#
# Embora simples, esse comportamento descreve razoavelmente bem a fase exponencial de muitos processos fermentativos.
#
# Entretanto, ele assume que a taxa específica de crescimento $\mu$ permanece constante durante todo o experimento.
#
# Será que essa hipótese é consistente com os dados experimentais analisados anteriormente?

# %%
plt.figure(figsize=(7,4))

plt.plot(df_taxa["Tempo médio (h)"],
         df_taxa["Taxa específica (1/h)"],
         marker='o')

plt.xlabel("Tempo (h)")
plt.ylabel("μ (1/h)")
plt.grid()

plt.show()

# %% [markdown]
# Observando o gráfico acima, percebemos que a taxa específica não permanece constante.
#
# Portanto, precisamos construir um modelo mais realista.

# %% [markdown]
# ### O modelo de Monod
#
# Uma das principais causas da redução da taxa de crescimento é a diminuição da disponibilidade de substrato ao longo da fermentação.
#
# O modelo proposto por Jacques Monod descreve esse comportamento assumindo que a taxa específica depende da concentração de substrato disponível.
#
# Nesse modelo,
#
# $$
# μ=μ_{max} \frac{S}{K_s+S}
# $$
#
# - $\mu_{max}$ representa a taxa específica máxima de crescimento;
# - $S$ é a concentração de substrato;
# - $K_s$ é a constante de saturação.
#
# Quando existe muito substrato disponível, o crescimento aproxima-se de $\mu_{max}$.
#
# À medida que o substrato é consumido, a taxa específica diminui.

# %%
S = np.linspace(0,25,200)

mu_max = 0.45
Ks = 3

mu = mu_max*S/(Ks+S)

# %%
plt.figure(figsize=(7,4))

plt.plot(S,mu)

plt.xlabel("Substrato (g/L)")
plt.ylabel("μ (1/h)")

plt.grid()

plt.show()

# %% [markdown]
# ### Pergunta
# - O que acontece quando mudamos $\mu_{max}$?
# - O que acontece quando mudamos $K_s$?

# %%
plt.figure(figsize=(7,4))

for mu_max in [0.3,0.5,0.7]:

    mu = mu_max*S/(3+S)

    plt.plot(S,mu,label=f"μmax={mu_max}")

plt.xlabel("Substrato (g/L)")
plt.ylabel("μ (1/h)")

plt.legend()

plt.grid()

plt.show()

# %%
plt.figure(figsize=(7,4))

for Ks in [1,3,6]:

    mu = 0.5*S/(Ks+S)

    plt.plot(S,mu,label=f"Ks={Ks}")

plt.xlabel("Substrato (g/L)")
plt.ylabel("μ (1/h)")

plt.legend()

plt.grid()

plt.show()

# %% [markdown]
# Observe que dois parâmetros controlam o comportamento do modelo.
#
# O parâmetro $\mu_{max}$ determina a velocidade máxima de crescimento que o microrganismo pode atingir.
#
# Já $K_s$ controla a sensibilidade do crescimento à disponibilidade de substrato. Quanto menor seu valor, maior é a capacidade do microrganismo de crescer mesmo em baixas concentrações de substrato.
#
# Esses parâmetros são característicos de cada sistema biológico e normalmente são obtidos a partir de dados experimentais.

# %% [markdown]
# ## **Conclusão – Encerrando o primeiro dia**
#
# Hoje aprendemos a utilizar Python para:
#
# - realizar cálculos científicos;
# - manipular dados experimentais;
# - construir gráficos;
# - calcular parâmetros cinéticos;
# - organizar códigos utilizando funções;
# - compreender como modelos matemáticos podem representar o crescimento microbiano.
#
# Entretanto, ainda existe uma pergunta importante:
#
# **Como determinar os valores de** $\mu_{max}$ **e** $K_s$ **utilizando os dados experimentais?**
#
# Essa será nossa primeira atividade no segundo dia do workshop.
